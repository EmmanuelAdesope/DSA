# %% [markdown]
# <a href="https://colab.research.google.com/github/EmmanuelAdesope/DSA/blob/main/lossylossylossy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import struct
import os

# Function to compress and pack 32-bit float
def compress_and_pack_float_32(x, k):
    """Compress a 32-bit float by zeroing out the last k bits of the mantissa and pack as an integer."""
    if x == 0.0:
        return 0
    binary = struct.unpack('I', struct.pack('f', x))[0]
    mantissa_mask = (1 << 23) - 1           # Bits 0-22
    lower_mask = (1 << k) - 1               # Bits 0 to k-1
    mask = mantissa_mask & ~lower_mask      # Keep bits k to 22
    compressed_binary = (binary & ~mantissa_mask) | (binary & mask)
    return compressed_binary >> k

# Function to unpack compressed data back to 32-bit float
def unpack_float_32(compressed, k):
    """Unpack a compressed integer back to a 32-bit float."""
    restored_binary = compressed << k
    restored_binary = np.uint32(restored_binary)
    return struct.unpack('f', struct.pack('I', restored_binary))[0]

# Function to calculate and print statistics
def calculate_and_print_stats(distributions):
    """Calculate and print mean and std for full-precision and compressed data."""
    for dist_name in distributions:
        full_filename = f'{dist_name}_full.bin'
        if not os.path.exists(full_filename):
            print(f"Error: '{full_filename}' not found.")
            continue
        full_data = np.fromfile(full_filename, dtype=np.float32)
        print(f"\n### {dist_name.capitalize()} Full-Precision Data Statistics ###")
        print(f"Mean: {np.mean(full_data):.10f}")
        print(f"Standard Deviation: {np.std(full_data):.10f}")

        for k in range(8, 17):
            filename = f'{dist_name}_compressed_k{k}.bin'
            if not os.path.exists(filename):
                print(f"Error: '{filename}' not found.")
                continue

            bytes_per_sample = (32 - k + 7) // 8
            if bytes_per_sample == 3:
                packed = np.fromfile(filename, dtype=np.uint8).reshape(-1, 3)
                padded = np.hstack((packed, np.zeros((packed.shape[0], 1), dtype=np.uint8)))
                compressed_int = np.frombuffer(padded.tobytes(), dtype=np.uint32)
            elif bytes_per_sample == 2:
                compressed_int = np.fromfile(filename, dtype=np.uint16).astype(np.uint32)
            else:
                print(f"Unsupported bytes_per_sample ({bytes_per_sample}) for k={k}")
                continue

            compressed_data = np.array([unpack_float_32(val, k) for val in compressed_int], dtype=np.float32)
            print(f"\n### {dist_name.capitalize()} Compressed Data (k={k}) Statistics ###")
            print(f"Mean: {np.mean(compressed_data):.10f}")
            print(f"Standard Deviation: {np.std(compressed_data):.10f}")

# New function to compute and print Mean Squared Error
def calculate_and_print_mse(distributions):
    """Calculate and print MSE between full-precision and compressed data."""
    for dist_name in distributions:
        full_filename = f'{dist_name}_full.bin'
        if not os.path.exists(full_filename):
            print(f"Error: '{full_filename}' not found.")
            continue
        full_data = np.fromfile(full_filename, dtype=np.float32)
        print(f"\n### {dist_name.capitalize()} Mean Squared Error ###")

        for k in range(8, 17):
            filename = f'{dist_name}_compressed_k{k}.bin'
            if not os.path.exists(filename):
                print(f"Error: '{filename}' not found.")
                continue

            bytes_per_sample = (32 - k + 7) // 8
            if bytes_per_sample == 3:
                packed = np.fromfile(filename, dtype=np.uint8).reshape(-1, 3)
                padded = np.hstack((packed, np.zeros((packed.shape[0], 1), dtype=np.uint8)))
                compressed_int = np.frombuffer(padded.tobytes(), dtype=np.uint32)
            elif bytes_per_sample == 2:
                compressed_int = np.fromfile(filename, dtype=np.uint16).astype(np.uint32)
            else:
                print(f"Unsupported bytes_per_sample ({bytes_per_sample}) for k={k}")
                continue

            compressed_data = np.array([unpack_float_32(val, k) for val in compressed_int], dtype=np.float32)
            mse = np.mean((full_data - compressed_data) ** 2)
            print(f"MSE for k={k}: {mse:.10e}")

# Generate datasets for three distributions
n = 1_000_000  # 1 million samples
distributions = {
    'uniform': (1.0 + np.random.uniform(0, 1e-5, n)).astype(np.float32),
    'gaussian': np.random.normal(1.0, 1e-5, n).astype(np.float32),
    'exponential': np.random.exponential(1e-5, n).astype(np.float32)
}
for dist_name, data in distributions.items():
    print(f"Generated {n} 32-bit float samples for {dist_name} distribution.")

# Compress data for k=8 to 16
k_values = list(range(8, 17))  # k = 8, 9, 10, ..., 16
compressed_packed_data = {}
for dist_name, data in distributions.items():
    compressed_packed_data[dist_name] = {}
    for k in k_values:
        compressed_packed_data[dist_name][k] = np.array(
            [compress_and_pack_float_32(x, k) for x in data], dtype=np.uint32
        )
        print(f"Compressed {dist_name} data with k={k} (reducing to {32 - k} bits).")

# Save full-precision and compressed data
for dist_name, data in distributions.items():
    full_filename = f'{dist_name}_full.bin'
    data.tofile(full_filename)
    print(f"Saved full-precision {dist_name} data to '{full_filename}'.")

    for k in k_values:
        bytes_per_sample = (32 - k + 7) // 8
        filename = f'{dist_name}_compressed_k{k}.bin'
        if bytes_per_sample == 3:  # For k=8 to 12 (24 to 20 bits)
            packed = np.frombuffer(compressed_packed_data[dist_name][k].tobytes(), dtype=np.uint8).reshape(-1, 4)[:, :3]
            packed.tofile(filename)
        elif bytes_per_sample == 2:  # For k=13 to 16 (19 to 16 bits)
            compressed_packed_data[dist_name][k].astype(np.uint16).tofile(filename)
        print(f"Saved compressed {dist_name} data (k={k}) to '{filename}' as {bytes_per_sample}-byte integers.")

# Measure file sizes
print("\nFile Sizes:")
for dist_name in distributions:
    full_size = os.path.getsize(f'{dist_name}_full.bin')
    print(f"{dist_name.capitalize()} full-precision file size: {full_size} bytes")

    compressed_sizes = {}
    for k in k_values:
        compressed_sizes[k] = os.path.getsize(f'{dist_name}_compressed_k{k}.bin')
        print(f"{dist_name.capitalize()} compressed file size (k={k}, {32 - k} bits): {compressed_sizes[k]} bytes")

# Calculate storage savings
print("\nStorage Savings:")
for dist_name in distributions:
    full_size = os.path.getsize(f'{dist_name}_full.bin')
    print(f"\n{dist_name.capitalize()}:")
    for k in k_values:
        savings = (full_size - os.path.getsize(f'{dist_name}_compressed_k{k}.bin')) / full_size * 100
        print(f"For k={k} ({32 - k} bits): {savings:.2f}%")

# Calculate and print statistics
calculate_and_print_stats(distributions)

# Calculate and print MSE
calculate_and_print_mse(distributions)
# Out:
# Generated 1000000 32-bit float samples for uniform distribution.
# Generated 1000000 32-bit float samples for gaussian distribution.
# Generated 1000000 32-bit float samples for exponential distribution.
# Compressed uniform data with k=8 (reducing to 24 bits).
# Compressed uniform data with k=9 (reducing to 23 bits).
# Compressed uniform data with k=10 (reducing to 22 bits).
# Compressed uniform data with k=11 (reducing to 21 bits).
# Compressed uniform data with k=12 (reducing to 20 bits).
# Compressed uniform data with k=13 (reducing to 19 bits).
# Compressed uniform data with k=14 (reducing to 18 bits).
# Compressed uniform data with k=15 (reducing to 17 bits).
# Compressed uniform data with k=16 (reducing to 16 bits).
# Compressed gaussian data with k=8 (reducing to 24 bits).
# Compressed gaussian data with k=9 (reducing to 23 bits).
# Compressed gaussian data with k=10 (reducing to 22 bits).
# Compressed gaussian data with k=11 (reducing to 21 bits).
# Compressed gaussian data with k=12 (reducing to 20 bits).
# Compressed gaussian data with k=13 (reducing to 19 bits).
# Compressed gaussian data with k=14 (reducing to 18 bits).
# Compressed gaussian data with k=15 (reducing to 17 bits).
# Compressed gaussian data with k=16 (reducing to 16 bits).
# Compressed exponential data with k=8 (reducing to 24 bits).
# Compressed exponential data with k=9 (reducing to 23 bits).
# Compressed exponential data with k=10 (reducing to 22 bits).
# Compressed exponential data with k=11 (reducing to 21 bits).
# Compressed exponential data with k=12 (reducing to 20 bits).
# Compressed exponential data with k=13 (reducing to 19 bits).
# Compressed exponential data with k=14 (reducing to 18 bits).
# Compressed exponential data with k=15 (reducing to 17 bits).
# Compressed exponential data with k=16 (reducing to 16 bits).
# Saved full-precision uniform data to 'uniform_full.bin'.
# Saved compressed uniform data (k=8) to 'uniform_compressed_k8.bin' as 3-byte integers.
# Saved compressed uniform data (k=9) to 'uniform_compressed_k9.bin' as 3-byte integers.
# Saved compressed uniform data (k=10) to 'uniform_compressed_k10.bin' as 3-byte integers.
# Saved compressed uniform data (k=11) to 'uniform_compressed_k11.bin' as 3-byte integers.
# Saved compressed uniform data (k=12) to 'uniform_compressed_k12.bin' as 3-byte integers.
# Saved compressed uniform data (k=13) to 'uniform_compressed_k13.bin' as 3-byte integers.
# Saved compressed uniform data (k=14) to 'uniform_compressed_k14.bin' as 3-byte integers.
# Saved compressed uniform data (k=15) to 'uniform_compressed_k15.bin' as 3-byte integers.
# Saved compressed uniform data (k=16) to 'uniform_compressed_k16.bin' as 2-byte integers.
# Saved full-precision gaussian data to 'gaussian_full.bin'.
# Saved compressed gaussian data (k=8) to 'gaussian_compressed_k8.bin' as 3-byte integers.
# Saved compressed gaussian data (k=9) to 'gaussian_compressed_k9.bin' as 3-byte integers.
# Saved compressed gaussian data (k=10) to 'gaussian_compressed_k10.bin' as 3-byte integers.
# Saved compressed gaussian data (k=11) to 'gaussian_compressed_k11.bin' as 3-byte integers.
# Saved compressed gaussian data (k=12) to 'gaussian_compressed_k12.bin' as 3-byte integers.
# Saved compressed gaussian data (k=13) to 'gaussian_compressed_k13.bin' as 3-byte integers.
# Saved compressed gaussian data (k=14) to 'gaussian_compressed_k14.bin' as 3-byte integers.
# Saved compressed gaussian data (k=15) to 'gaussian_compressed_k15.bin' as 3-byte integers.
# Saved compressed gaussian data (k=16) to 'gaussian_compressed_k16.bin' as 2-byte integers.
# Saved full-precision exponential data to 'exponential_full.bin'.
# Saved compressed exponential data (k=8) to 'exponential_compressed_k8.bin' as 3-byte integers.
# Saved compressed exponential data (k=9) to 'exponential_compressed_k9.bin' as 3-byte integers.
# Saved compressed exponential data (k=10) to 'exponential_compressed_k10.bin' as 3-byte integers.
# Saved compressed exponential data (k=11) to 'exponential_compressed_k11.bin' as 3-byte integers.
# Saved compressed exponential data (k=12) to 'exponential_compressed_k12.bin' as 3-byte integers.
# Saved compressed exponential data (k=13) to 'exponential_compressed_k13.bin' as 3-byte integers.
# Saved compressed exponential data (k=14) to 'exponential_compressed_k14.bin' as 3-byte integers.
# Saved compressed exponential data (k=15) to 'exponential_compressed_k15.bin' as 3-byte integers.
# Saved compressed exponential data (k=16) to 'exponential_compressed_k16.bin' as 2-byte integers.
#
# File Sizes:
# Uniform full-precision file size: 4000000 bytes
# Uniform compressed file size (k=8, 24 bits): 3000000 bytes
# Uniform compressed file size (k=9, 23 bits): 3000000 bytes
# Uniform compressed file size (k=10, 22 bits): 3000000 bytes
# Uniform compressed file size (k=11, 21 bits): 3000000 bytes
# Uniform compressed file size (k=12, 20 bits): 3000000 bytes
# Uniform compressed file size (k=13, 19 bits): 3000000 bytes
# Uniform compressed file size (k=14, 18 bits): 3000000 bytes
# Uniform compressed file size (k=15, 17 bits): 3000000 bytes
# Uniform compressed file size (k=16, 16 bits): 2000000 bytes
# Gaussian full-precision file size: 4000000 bytes
# Gaussian compressed file size (k=8, 24 bits): 3000000 bytes
# Gaussian compressed file size (k=9, 23 bits): 3000000 bytes
# Gaussian compressed file size (k=10, 22 bits): 3000000 bytes
# Gaussian compressed file size (k=11, 21 bits): 3000000 bytes
# Gaussian compressed file size (k=12, 20 bits): 3000000 bytes
# Gaussian compressed file size (k=13, 19 bits): 3000000 bytes
# Gaussian compressed file size (k=14, 18 bits): 3000000 bytes
# Gaussian compressed file size (k=15, 17 bits): 3000000 bytes
# Gaussian compressed file size (k=16, 16 bits): 2000000 bytes
# Exponential full-precision file size: 4000000 bytes
# Exponential compressed file size (k=8, 24 bits): 3000000 bytes
# Exponential compressed file size (k=9, 23 bits): 3000000 bytes
# Exponential compressed file size (k=10, 22 bits): 3000000 bytes
# Exponential compressed file size (k=11, 21 bits): 3000000 bytes
# Exponential compressed file size (k=12, 20 bits): 3000000 bytes
# Exponential compressed file size (k=13, 19 bits): 3000000 bytes
# Exponential compressed file size (k=14, 18 bits): 3000000 bytes
# Exponential compressed file size (k=15, 17 bits): 3000000 bytes
# Exponential compressed file size (k=16, 16 bits): 2000000 bytes
#
# Storage Savings:
#
# Uniform:
# For k=8 (24 bits): 25.00%
# For k=9 (23 bits): 25.00%
# For k=10 (22 bits): 25.00%
# For k=11 (21 bits): 25.00%
# For k=12 (20 bits): 25.00%
# For k=13 (19 bits): 25.00%
# For k=14 (18 bits): 25.00%
# For k=15 (17 bits): 25.00%
# For k=16 (16 bits): 50.00%
#
# Gaussian:
# For k=8 (24 bits): 25.00%
# For k=9 (23 bits): 25.00%
# For k=10 (22 bits): 25.00%
# For k=11 (21 bits): 25.00%
# For k=12 (20 bits): 25.00%
# For k=13 (19 bits): 25.00%
# For k=14 (18 bits): 25.00%
# For k=15 (17 bits): 25.00%
# For k=16 (16 bits): 50.00%
#
# Exponential:
# For k=8 (24 bits): 25.00%
# For k=9 (23 bits): 25.00%
# For k=10 (22 bits): 25.00%
# For k=11 (21 bits): 25.00%
# For k=12 (20 bits): 25.00%
# For k=13 (19 bits): 25.00%
# For k=14 (18 bits): 25.00%
# For k=15 (17 bits): 25.00%
# For k=16 (16 bits): 50.00%
#
# ### Uniform Full-Precision Data Statistics ###
# Mean: 1.0000059605
# Standard Deviation: 0.0000030414
#
# ### Uniform Compressed Data (k=8) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Uniform Compressed Data (k=9) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Uniform Compressed Data (k=10) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Uniform Compressed Data (k=11) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Uniform Compressed Data (k=12) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Uniform Compressed Data (k=13) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Uniform Compressed Data (k=14) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Uniform Compressed Data (k=15) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Uniform Compressed Data (k=16) Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000000000
#
# ### Gaussian Full-Precision Data Statistics ###
# Mean: 1.0000000000
# Standard Deviation: 0.0000099889
#
# ### Gaussian Compressed Data (k=8) Statistics ###
# Mean: 0.9999921918
# Standard Deviation: 0.0000094793
#
# ### Gaussian Compressed Data (k=9) Statistics ###
# Mean: 0.9999847412
# Standard Deviation: 0.0000153213
#
# ### Gaussian Compressed Data (k=10) Statistics ###
# Mean: 0.9999694824
# Standard Deviation: 0.0000305176
#
# ### Gaussian Compressed Data (k=11) Statistics ###
# Mean: 0.9999390244
# Standard Deviation: 0.0000610351
#
# ### Gaussian Compressed Data (k=12) Statistics ###
# Mean: 0.9998779893
# Standard Deviation: 0.0001220702
#
# ### Gaussian Compressed Data (k=13) Statistics ###
# Mean: 0.9997560978
# Standard Deviation: 0.0002441404
#
# ### Gaussian Compressed Data (k=14) Statistics ###
# Mean: 0.9995126128
# Standard Deviation: 0.0004882807
#
# ### Gaussian Compressed Data (k=15) Statistics ###
# Mean: 0.9990249872
# Standard Deviation: 0.0009765614
#
# ### Gaussian Compressed Data (k=16) Statistics ###
# Mean: 0.9980498552
# Standard Deviation: 0.0019531226
#
# ### Exponential Full-Precision Data Statistics ###
# Mean: 0.0000099934
# Standard Deviation: 0.0000099989
#
# ### Exponential Compressed Data (k=8) Statistics ###
# Mean: 0.0000099933
# Standard Deviation: 0.0000099988
#
# ### Exponential Compressed Data (k=9) Statistics ###
# Mean: 0.0000099931
# Standard Deviation: 0.0000099987
#
# ### Exponential Compressed Data (k=10) Statistics ###
# Mean: 0.0000099929
# Standard Deviation: 0.0000099985
#
# ### Exponential Compressed Data (k=11) Statistics ###
# Mean: 0.0000099925
# Standard Deviation: 0.0000099981
#
# ### Exponential Compressed Data (k=12) Statistics ###
# Mean: 0.0000099916
# Standard Deviation: 0.0000099972
#
# ### Exponential Compressed Data (k=13) Statistics ###
# Mean: 0.0000099898
# Standard Deviation: 0.0000099954
#
# ### Exponential Compressed Data (k=14) Statistics ###
# Mean: 0.0000099863
# Standard Deviation: 0.0000099919
#
# ### Exponential Compressed Data (k=15) Statistics ###
# Mean: 0.0000099793
# Standard Deviation: 0.0000099848
#
# ### Exponential Compressed Data (k=16) Statistics ###
# Mean: 0.0000099653
# Standard Deviation: 0.0000099709
#
# ### Uniform Mean Squared Error ###
# MSE for k=8: 3.3404005256e-11
# MSE for k=9: 3.3404005256e-11
# MSE for k=10: 3.3404005256e-11
# MSE for k=11: 3.3404005256e-11
# MSE for k=12: 3.3404005256e-11
# MSE for k=13: 3.3404005256e-11
# MSE for k=14: 3.3404005256e-11
# MSE for k=15: 3.3404005256e-11
# MSE for k=16: 3.3404005256e-11
#
# ### Gaussian Mean Squared Error ###
# MSE for k=8: 9.9540348186e-11
# MSE for k=9: 3.2211447398e-10
# MSE for k=10: 1.4728134268e-09
# MSE for k=11: 6.5654264247e-09
# MSE for k=12: 2.7909376143e-08
# MSE for k=13: 1.1523220422e-07
# MSE for k=14: 4.6841736889e-07
# MSE for k=15: 1.8889465991e-06
# MSE for k=16: 7.5866400948e-06
#
# ### Exponential Mean Squared Error ###
# MSE for k=8: 3.3416901213e-20
# MSE for k=9: 1.3373081954e-19
# MSE for k=10: 5.3710605272e-19
# MSE for k=11: 2.1413207974e-18
# MSE for k=12: 8.5703860666e-18
# MSE for k=13: 3.4266598767e-17
# MSE for k=14: 1.3717486823e-16
# MSE for k=15: 5.4906168537e-16
# MSE for k=16: 2.1824847854e-15
